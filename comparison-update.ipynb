# %%
import pandas as pd
import umap
import re
import jscatter
import ast  # ast.literal_eval safely evaluates a string containing a Python literal expression

# Initialize UMAP. Reduce dimensionality t 2D for easy visualization.
# Create a UMAP instance with custom parameters
reducer = umap.UMAP(
    n_neighbors=120,
    n_components=2,
    metric='euclidean',
    min_dist=5.5,
    spread=6.5,
    learning_rate=1.0,
    n_epochs=200,
    init='spectral',
    random_state=29,
)

def remove_slash(s):
    return s[1:]

def extract_substring(s):
    # Use a regular expression to find the point at which to stop
    match = re.search(r'_(p|m|sw|s)', s)
    if match:
        return s[:match.start()]
    return s  # Return the whole string if no match is found

def attach_image(s):    
    return "https://raw.githubusercontent.com/huyen-nguyen/spec-image-embeddings/main/screenshots/" + s[:-4] + "png"  # Return the whole string if no match is found

def attach_image_from_non_spec(s):    
    return "https://raw.githubusercontent.com/huyen-nguyen/spec-image-embeddings/main/screenshots/" + s  # Return the whole string if no match is found

# %% [markdown]
# ## Embeddings from Specs, LiT, and CLIP

# %%
# --------- Load label file ---------
df_label = pd.read_csv('labels.csv')


# --------- Load Spec Data and Apply UMAP ----------

# Load the CSV file into a DataFrame
df_spec = pd.read_csv('embeddings/spec_embeddings.csv')

# Assume 'filename' is the column to exclude from embeddings
filename_spec = df_spec['filename']

# Extract all other columns as embeddings
embeddings_spec = df_spec.drop('filename', axis=1)

# Apply UMAP 
umap_embeddings_spec = reducer.fit_transform(embeddings_spec)

# --------- Load LiT Data and Apply UMAP ----------

# Specify column names
column_names = ['Filename', 'Embeddings']

# Load the CSV file
df_lit = pd.read_csv('embeddings/image_lit_embeddings.tsv', delimiter='\t', names=column_names)

df_lit['embeddings'] = df_lit['Embeddings'].apply(ast.literal_eval)
df_lit['filename'] = df_lit['Filename'].apply(remove_slash)

# Accessing the embedding for the first row
first_embedding = df_lit.loc[0, 'embeddings']

# Assuming 'df' is your DataFrame and it contains an 'embeddings' column with your embeddings data
# Convert embeddings list into a proper format if necessary
embeddings = list(df_lit['embeddings'])

umap_embeddings_lit = reducer.fit_transform(embeddings)

# --------- Load CLIP Data and Apply UMAP ----------

# Load the CSV file
df_clip = pd.read_csv('embeddings/image_clip_embeddings.csv')

df_clip['embeddings'] = df_clip['Embeddings'].apply(ast.literal_eval)
# Accessing the embedding for the first row
first_embedding = df_clip.loc[0, 'embeddings']

# Assuming 'df' is your DataFrame and it contains an 'embeddings' column with your embeddings data
# Convert embeddings list into a proper format if necessary
embeddings = list(df_clip['embeddings'])

umap_embeddings_clip = reducer.fit_transform(embeddings)

# --------- Prepare labels ---------

# Apply the function to the 'Label' column
df_spec['label'] = df_spec['filename'].apply(extract_substring)
df_lit['label'] = df_lit['filename'].apply(extract_substring)
df_clip['label'] = df_clip['Filename'].apply(extract_substring)

# Display the DataFrame to see the original and trimmed labels
# print(df)
# Out:
# /Users/huyennguyen/anaconda3/envs/embs_venv/lib/python3.12/site-packages/umap/umap_.py:1394: RuntimeWarning: divide by zero encountered in power
#   return 1.0 / (1.0 + a * x ** (2 * b))
# /Users/huyennguyen/anaconda3/envs/embs_venv/lib/python3.12/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/huyennguyen/anaconda3/envs/embs_venv/lib/python3.12/site-packages/umap/umap_.py:1394: RuntimeWarning: divide by zero encountered in power
#   return 1.0 / (1.0 + a * x ** (2 * b))
# /Users/huyennguyen/anaconda3/envs/embs_venv/lib/python3.12/site-packages/umap/umap_.py:1394: RuntimeWarning: divide by zero encountered in power
#   return 1.0 / (1.0 + a * x ** (2 * b))

# %% [markdown]
# ## Embeddings from BiomedCLIP

# %%
# Load the parquet file
df_bio = pd.read_parquet('embeddings/biomedclip_embeddings.parquet')
# Get rid of the directory path
df_bio['image'] = df_bio['image'].apply(lambda x: x.split('/')[-1])

def attach_image(s):    
    return "https://raw.githubusercontent.com/huyen-nguyen/spec-image-embeddings/main/screenshots/" + s  # Return the whole string if no match is found

df_bio["url"] = df_bio['image'].apply(attach_image)

#  --------- Prepare labels ---------
import re
def extract_substring(s):
    # Use a regular expression to find the point at which to stop
    match = re.search(r'_(p|m|sw|s)', s)
    if match:
        return s[:match.start()]
    return s  # Return the whole string if no match is found


# Apply the function to the 'Label' column
df_bio['Label'] = df_bio['image'].apply(extract_substring)
    
df_bio
# Out:
#                                            image  \
# 0                       heatmap_sw_1_2_s_1_0.png
# 1           two_by_two_p_4_m_10_sw_0_7_s_1_2.png
# 2        multiple_view_p_2_m_12_sw_0_7_s_0_7.png
# 3      two_by_two_uneven_w_m_20_sw_0_7_s_0_7.png
# 4         multiple_view_p_1_m_8_sw_1_2_s_1_0.png
# ...                                          ...
# 7291  three_composite_v_p_0_m_0_sw_1_2_s_2_0.png
# 7292    two_by_two_uneven_h_p_0_sw_0_7_s_1_2.png
# 7293        three_composite_m_9_sw_0_7_s_1_2.png
# 7294   multi_view_link_p_0_m_11_sw_1_0_s_0_7.png
# 7295     multiple_view_p_3_m_13_sw_1_2_s_1_0.png
#
#                            top_label  \
# 0                            heatmap
# 1             genomics visualization
# 2     circular genomic visualization
# 3             genomics visualization
# 4     circular genomic visualization
# ...                              ...
# 7291                        dot plot
# 7292          genomics visualization
# 7293          genomics visualization
# 7294  circular genomic visualization
# 7295  circular genomic visualization
#
#                                         clip_embeddings  \
# 0     [0.022331731, 0.007818277, -0.16542432, 0.0080...
# 1     [0.019216416, 0.03744839, -0.12684523, -0.0058...
# 2     [-0.0016217616, -0.051115554, -0.07445832, -0....
# 3     [-0.0015807527, 0.038776863, -0.13082261, 0.05...
# 4     [-0.002367256, -0.0421267, -0.04676023, -0.033...
# ...                                                 ...
# 7291  [0.039080445, 0.014055151, -0.1260775, -0.0130...
# 7292  [0.025236, 0.035443608, -0.09266704, -0.011160...
# 7293  [0.0100230975, -0.0006275425, -0.14095412, -0....
# 7294  [-0.026482897, -0.019669285, -0.04968637, -0.0...
# 7295  [0.010469665, -0.04382261, -0.058548458, -0.01...
#
#                                                     url                Label
# 0     https://raw.githubusercontent.com/huyen-nguyen...              heatmap
# 1     https://raw.githubusercontent.com/huyen-nguyen...           two_by_two
# 2     https://raw.githubusercontent.com/huyen-nguyen...        multiple_view
# 3     https://raw.githubusercontent.com/huyen-nguyen...  two_by_two_uneven_w
# 4     https://raw.githubusercontent.com/huyen-nguyen...        multiple_view
# ...                                                 ...                  ...
# 7291  https://raw.githubusercontent.com/huyen-nguyen...    three_composite_v
# 7292  https://raw.githubusercontent.com/huyen-nguyen...  two_by_two_uneven_h
# 7293  https://raw.githubusercontent.com/huyen-nguyen...      three_composite
# 7294  https://raw.githubusercontent.com/huyen-nguyen...      multi_view_link
# 7295  https://raw.githubusercontent.com/huyen-nguyen...        multiple_view
#
# [7296 rows x 5 columns]

# %%
embeddings = list(df_bio['clip_embeddings'])
umap_embeddings_bio = reducer.fit_transform(embeddings)

embedding_df = pd.DataFrame(umap_embeddings_bio, columns=['UMAP_1', 'UMAP_2'])
embedding_df['url'] = df_bio["url"]
embedding_df['identifier'] = df_bio['image'].str.split('.').str[0]

df_bio['UMAP_1'] = embedding_df['UMAP_1']
df_bio['UMAP_2'] = embedding_df['UMAP_2']
# Out:
# /Users/huyennguyen/anaconda3/envs/embs_venv/lib/python3.12/site-packages/umap/umap_.py:1394: RuntimeWarning: divide by zero encountered in power
#   return 1.0 / (1.0 + a * x ** (2 * b))

# %%
# ------------ Merging DataFrames ------------
umap_embeddings_bio = pd.merge(embedding_df, df_label, on='identifier', how='inner')  
umap_embeddings_bio
# Out:
#          UMAP_1     UMAP_2                                                url  \
# 0    -23.259916 -14.080674  https://raw.githubusercontent.com/huyen-nguyen...
# 1     23.363602  50.739025  https://raw.githubusercontent.com/huyen-nguyen...
# 2     46.658939 -22.275047  https://raw.githubusercontent.com/huyen-nguyen...
# 3     35.035782  15.762679  https://raw.githubusercontent.com/huyen-nguyen...
# 4     16.445215 -20.306992  https://raw.githubusercontent.com/huyen-nguyen...
# ...         ...        ...                                                ...
# 7291   4.570871  26.685818  https://raw.githubusercontent.com/huyen-nguyen...
# 7292  21.749504  22.989798  https://raw.githubusercontent.com/huyen-nguyen...
# 7293   0.739522  22.906290  https://raw.githubusercontent.com/huyen-nguyen...
# 7294  -1.398568 -15.254950  https://raw.githubusercontent.com/huyen-nguyen...
# 7295  23.257349 -15.456118  https://raw.githubusercontent.com/huyen-nguyen...
#
#                                   identifier  data_label   layout_label  \
# 0                       heatmap_sw_1_2_s_1_0  contiguous         linear
# 1           two_by_two_p_4_m_10_sw_0_7_s_1_2  contiguous         linear
# 2        multiple_view_p_2_m_12_sw_0_7_s_0_7  contiguous  multi_layouts
# 3      two_by_two_uneven_w_m_20_sw_0_7_s_0_7  contiguous         linear
# 4         multiple_view_p_1_m_8_sw_1_2_s_1_0  contiguous  multi_layouts
# ...                                      ...         ...            ...
# 7291  three_composite_v_p_0_m_0_sw_1_2_s_2_0  contiguous         linear
# 7292    two_by_two_uneven_h_p_0_sw_0_7_s_1_2  contiguous         linear
# 7293        three_composite_m_9_sw_0_7_s_1_2  contiguous         linear
# 7294   multi_view_link_p_0_m_11_sw_1_0_s_0_7  contiguous  multi_layouts
# 7295     multiple_view_p_3_m_13_sw_1_2_s_1_0  contiguous  multi_layouts
#
#        arrangement_label   mark_label alignment_label       orientation_label
# 0        no_arrangements         rect           stack  horizontal_orientation
# 1     multi_arrangements    area_line           stack  horizontal_orientation
# 2     multi_arrangements  multi_marks         overlay  horizontal_orientation
# 3     multi_arrangements  multi_marks           stack  horizontal_orientation
# 4     multi_arrangements  multi_marks         overlay  horizontal_orientation
# ...                  ...          ...             ...                     ...
# 7291  multi_arrangements   line_point           stack  horizontal_orientation
# 7292  multi_arrangements  multi_marks           stack  horizontal_orientation
# 7293  multi_arrangements  multi_marks           stack  horizontal_orientation
# 7294  multi_arrangements  multi_marks           stack  horizontal_orientation
# 7295  multi_arrangements  multi_marks         overlay  horizontal_orientation
#
# [7296 rows x 10 columns]

# %%
umap_embeddings_clip
# Out:
#          UMAP_1     UMAP_2                Label  \
# 0     16.289434  28.691895              heatmap
# 1    -17.417547  58.689529           two_by_two
# 2      1.790170 -46.233479        multiple_view
# 3    -18.295984  42.681408  two_by_two_uneven_w
# 4    -19.343306 -22.976347        multiple_view
# ...         ...        ...                  ...
# 7291  -5.079456  22.659405    three_composite_v
# 7292 -10.069639  28.670948  two_by_two_uneven_h
# 7293   2.789571  46.380150      three_composite
# 7294  -4.962070 -12.242511      multi_view_link
# 7295 -19.938204 -27.689222        multiple_view
#
#                                                     url  \
# 0     https://raw.githubusercontent.com/huyen-nguyen...
# 1     https://raw.githubusercontent.com/huyen-nguyen...
# 2     https://raw.githubusercontent.com/huyen-nguyen...
# 3     https://raw.githubusercontent.com/huyen-nguyen...
# 4     https://raw.githubusercontent.com/huyen-nguyen...
# ...                                                 ...
# 7291  https://raw.githubusercontent.com/huyen-nguyen...
# 7292  https://raw.githubusercontent.com/huyen-nguyen...
# 7293  https://raw.githubusercontent.com/huyen-nguyen...
# 7294  https://raw.githubusercontent.com/huyen-nguyen...
# 7295  https://raw.githubusercontent.com/huyen-nguyen...
#
#                                   identifier  data_label   layout_label  \
# 0                       heatmap_sw_1_2_s_1_0  contiguous         linear
# 1           two_by_two_p_4_m_10_sw_0_7_s_1_2  contiguous         linear
# 2        multiple_view_p_2_m_12_sw_0_7_s_0_7  contiguous  multi_layouts
# 3      two_by_two_uneven_w_m_20_sw_0_7_s_0_7  contiguous         linear
# 4         multiple_view_p_1_m_8_sw_1_2_s_1_0  contiguous  multi_layouts
# ...                                      ...         ...            ...
# 7291  three_composite_v_p_0_m_0_sw_1_2_s_2_0  contiguous         linear
# 7292    two_by_two_uneven_h_p_0_sw_0_7_s_1_2  contiguous         linear
# 7293        three_composite_m_9_sw_0_7_s_1_2  contiguous         linear
# 7294   multi_view_link_p_0_m_11_sw_1_0_s_0_7  contiguous  multi_layouts
# 7295     multiple_view_p_3_m_13_sw_1_2_s_1_0  contiguous  multi_layouts
#
#        arrangement_label   mark_label alignment_label       orientation_label
# 0        no_arrangements         rect           stack  horizontal_orientation
# 1     multi_arrangements    area_line           stack  horizontal_orientation
# 2     multi_arrangements  multi_marks         overlay  horizontal_orientation
# 3     multi_arrangements  multi_marks           stack  horizontal_orientation
# 4     multi_arrangements  multi_marks         overlay  horizontal_orientation
# ...                  ...          ...             ...                     ...
# 7291  multi_arrangements   line_point           stack  horizontal_orientation
# 7292  multi_arrangements  multi_marks           stack  horizontal_orientation
# 7293  multi_arrangements  multi_marks           stack  horizontal_orientation
# 7294  multi_arrangements  multi_marks           stack  horizontal_orientation
# 7295  multi_arrangements  multi_marks         overlay  horizontal_orientation
#
# [7296 rows x 11 columns]

# %%
# ----------- Apply labels -------------

# Convert the embeddings to a DataFrame
umap_embeddings_spec = pd.DataFrame(umap_embeddings_spec, columns=['UMAP_1', 'UMAP_2'])
umap_embeddings_lit = pd.DataFrame(umap_embeddings_lit, columns=['UMAP_1', 'UMAP_2'])
umap_embeddings_clip = pd.DataFrame(umap_embeddings_clip, columns=['UMAP_1', 'UMAP_2'])

# Add the labels to the DataFrame
umap_embeddings_spec['Label'] = df_spec['label']
umap_embeddings_lit['Label'] = df_lit['label']
umap_embeddings_clip['Label'] = df_clip['label']

umap_embeddings_spec["url"] = df_spec['filename'].apply(attach_image)
umap_embeddings_lit["url"] = df_lit['filename'].apply(attach_image_from_non_spec)
umap_embeddings_clip["url"] = df_clip['Filename'].apply(attach_image_from_non_spec)

# specify column for merge
umap_embeddings_spec['identifier'] = df_spec['filename'].str.split('.').str[0]
umap_embeddings_lit['identifier'] = df_lit['filename'].str.split('.').str[0]
umap_embeddings_clip['identifier'] = df_clip['Filename'].str.split('.').str[0]

# merge with label
umap_embeddings_spec = pd.merge(umap_embeddings_spec, df_label, on='identifier', how='inner')  
umap_embeddings_lit = pd.merge(umap_embeddings_lit, df_label, on='identifier', how='inner')  
umap_embeddings_clip = pd.merge(umap_embeddings_clip, df_label, on='identifier', how='inner')  


# ----------- Combine ------------- (below doesn't work because there are many more dimensions added with the ew labels)

combined = umap_embeddings_spec.merge(umap_embeddings_lit, on=['Label', 'url'], how='left').merge(umap_embeddings_clip, on=['Label', 'url'], how='left')
# combined = combined.rename(columns={"UMAP_1_x": "UMAP_1_spec", "UMAP_2_x": "UMAP_2_spec", "UMAP_1_y": "UMAP_1_lit", "UMAP_2_y": "UMAP_2_lit", "UMAP_1": "UMAP_1_clip", "UMAP_2": "UMAP_2_clip"})
combined

# Display the first few rows of the DataFrame
# print(umap_embeddings_spec.head())
# Out:
#        UMAP_1_x   UMAP_2_x                        Label  \
# 0     19.217770  -4.205412                   two_by_two
# 1     59.128807  79.548988              multi_view_link
# 2    -40.014015 -20.404404              single_cell_epi
# 3     -2.285565 -64.963257               two_horizontal
# 4     23.618654  50.159332  basic_two_horizontal_orient
# ...         ...        ...                          ...
# 7291  40.007118  56.111099                 two_vertical
# 7292  82.385056  -2.569696              gene_annotation
# 7293  49.994808  74.584877              multi_view_link
# 7294  -1.072334 -74.933830               two_horizontal
# 7295  26.956512  -4.471212          two_by_two_uneven_w
#
#                                                     url  \
# 0     https://raw.githubusercontent.com/huyen-nguyen...
# 1     https://raw.githubusercontent.com/huyen-nguyen...
# 2     https://raw.githubusercontent.com/huyen-nguyen...
# 3     https://raw.githubusercontent.com/huyen-nguyen...
# 4     https://raw.githubusercontent.com/huyen-nguyen...
# ...                                                 ...
# 7291  https://raw.githubusercontent.com/huyen-nguyen...
# 7292  https://raw.githubusercontent.com/huyen-nguyen...
# 7293  https://raw.githubusercontent.com/huyen-nguyen...
# 7294  https://raw.githubusercontent.com/huyen-nguyen...
# 7295  https://raw.githubusercontent.com/huyen-nguyen...
#
#                                       identifier_x      data_label_x  \
# 0                 two_by_two_p_4_m_11_sw_1_0_s_1_0        contiguous
# 1            multi_view_link_p_0_m_12_sw_2_0_s_1_0        contiguous
# 2     single_cell_epi_simple_p_0_m_18_sw_0_7_s_0_7  multi_data_types
# 3                  two_horizontal_m_9_sw_1_2_s_1_2        contiguous
# 4     basic_two_horizontal_orient_m_6_sw_1_0_s_1_0        contiguous
# ...                                            ...               ...
# 7291                 two_vertical_m_2_sw_0_5_s_0_5        contiguous
# 7292       gene_annotation_simple_p_3_sw_0_5_s_2_0            sparse
# 7293         multi_view_link_p_0_m_19_sw_1_2_s_1_2        contiguous
# 7294               two_horizontal_m_2_sw_2_0_s_1_0        contiguous
# 7295         two_by_two_uneven_w_m_18_sw_1_0_s_0_5        contiguous
#
#      layout_label_x arrangement_label_x   mark_label_x alignment_label_x  ...  \
# 0            linear  multi_arrangements    multi_marks             stack  ...
# 1     multi_layouts  multi_arrangements     line_point             stack  ...
# 2            linear            vertical    multi_marks           overlay  ...
# 3            linear              serial      area_line             stack  ...
# 4            linear     no_arrangements      area_line             stack  ...
# ...             ...                 ...            ...               ...  ...
# 7291         linear     no_arrangements     area_point             stack  ...
# 7292         linear  multi_arrangements  rect_triangle           overlay  ...
# 7293  multi_layouts  multi_arrangements      bar_point             stack  ...
# 7294         linear              serial     area_point             stack  ...
# 7295         linear  multi_arrangements     line_point             stack  ...
#
#      orientation_label_y  UMAP_1  UMAP_2 identifier data_label layout_label  \
# 0                    NaN     NaN     NaN        NaN        NaN          NaN
# 1                    NaN     NaN     NaN        NaN        NaN          NaN
# 2                    NaN     NaN     NaN        NaN        NaN          NaN
# 3                    NaN     NaN     NaN        NaN        NaN          NaN
# 4                    NaN     NaN     NaN        NaN        NaN          NaN
# ...                  ...     ...     ...        ...        ...          ...
# 7291                 NaN     NaN     NaN        NaN        NaN          NaN
# 7292                 NaN     NaN     NaN        NaN        NaN          NaN
# 7293                 NaN     NaN     NaN        NaN        NaN          NaN
# 7294                 NaN     NaN     NaN        NaN        NaN          NaN
# 7295                 NaN     NaN     NaN        NaN        NaN          NaN
#
#      arrangement_label mark_label alignment_label orientation_label
# 0                  NaN        NaN             NaN               NaN
# 1                  NaN        NaN             NaN               NaN
# 2                  NaN        NaN             NaN               NaN
# 3                  NaN        NaN             NaN               NaN
# 4                  NaN        NaN             NaN               NaN
# ...                ...        ...             ...               ...
# 7291               NaN        NaN             NaN               NaN
# 7292               NaN        NaN             NaN               NaN
# 7293               NaN        NaN             NaN               NaN
# 7294               NaN        NaN             NaN               NaN
# 7295               NaN        NaN             NaN               NaN
#
# [7296 rows x 29 columns]

# %%
# ----------- Config -------------

# API Reference: https://github.com/flekschas/jupyter-scatter
# and also https://github.com/flekschas/regl-scatterplot/#properties
config = {
    "color_by": 'data_label',
    "size": 5,
    "axes_labels": True,
    "height": 1000,
    "background": "dark",
    "legend": True,
    # "aspectRatio": 1,
    "opacity": 0.3,
    "axes_grid": True,
    "tooltip": True,
    "tooltip_preview": "url",
    "tooltip_preview_type": "image",
    "tooltip_preview_image_background_color": "white",
    "tooltip_properties": ["color"],
    "data": combined
}

# ----------- Plotting the results using jupyter scatter -----------
jscatter.compose(
    [
        jscatter.Scatter(
            x="UMAP_1_spec", y="UMAP_2_spec", **config,
        ),
        jscatter.Scatter(
            x="UMAP_1_lit", y="UMAP_2_lit", **config,
        ),
        jscatter.Scatter(
            x="UMAP_1_clip", y="UMAP_2_clip", **config
        )
    ],
    sync_selection=True,
    sync_hover=True,
    rows=1
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 29
#       5 config = {
#       6     "color_by": 'data_label',
#       7     "size": 5,
#    (...)
#      20     "data": combined
#      21 }
#      23 # ----------- Plotting the results using jupyter scatter -----------
#      24 jscatter.compose(
#      25     [
#      26         jscatter.Scatter(
#      27             x="UMAP_1_spec", y="UMAP_2_spec", **config,
#      28         ),
# ---> 29         jscatter.Scatter(
#      30             x="UMAP_1_lit", y="UMAP_2_lit", **config,
#      31         ),
#      32         jscatter.Scatter(
#      33             x="UMAP_1_clip", y="UMAP_2_clip", **config
#      34         )
#      35     ],
#      36     sync_selection=True,
#      37     sync_hover=True,
#      38     rows=1
#      39 )
#
# File ~/anaconda3/envs/embs_venv/lib/python3.12/site-packages/jscatter/jscatter.py:317, in Scatter.__init__(self, x, y, data, **kwargs)
#     314 self._zoom_on_filter = False
#     315 self._options = {}
# --> 317 self.x(x, kwargs.get('x_scale', UNDEF))
#     318 self.y(y, kwargs.get('y_scale', UNDEF))
#     319 self.width(kwargs.get('width', UNDEF))
#
# File ~/anaconda3/envs/embs_venv/lib/python3.12/site-packages/jscatter/jscatter.py:611, in Scatter.x(self, x, scale, **kwargs)
#     609 self._x_max = np.max(self._points[:, 0])
#     610 self._x_domain = [self._x_min, self._x_max]
# --> 611 self._x_histogram = get_histogram_from_df(
#     612     self._points[:, 0],
#     613     self.get_histogram_bins("x"),
#     614     self.get_histogram_range("x")
#     615 )
#     617 # Reset scale to new domain
#     618 if scale is UNDEF:
#
# File ~/anaconda3/envs/embs_venv/lib/python3.12/site-packages/jscatter/utils.py:121, in get_histogram_from_df(data, bins, range)
#     118     value_counts = _data.cat.codes.value_counts()
#     119     return [y for _, y in sorted(dict(value_counts / value_counts.sum()).items())]
# --> 121 hist = histogram(data, bins=bins, range=range)
#     123 return list(hist[0] / hist[0].max())
#
# File ~/anaconda3/envs/embs_venv/lib/python3.12/site-packages/numpy/lib/histograms.py:780, in histogram(a, bins, range, density, weights)
#     680 r"""
#     681 Compute the histogram of a dataset.
#     682
#    (...)
#     776
#     777 """
#     778 a, weights = _ravel_and_check_weights(a, weights)
# --> 780 bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     782 # Histogram is an integer or a float array depending on the weights.
#     783 if weights is None:
#
# File ~/anaconda3/envs/embs_venv/lib/python3.12/site-packages/numpy/lib/histograms.py:426, in _get_bin_edges(a, bins, range, weights)
#     423     if n_equal_bins < 1:
#     424         raise ValueError('`bins` must be positive, when an integer')
# --> 426     first_edge, last_edge = _get_outer_edges(a, range)
#     428 elif np.ndim(bins) == 1:
#     429     bin_edges = np.asarray(bins)
#
# File ~/anaconda3/envs/embs_venv/lib/python3.12/site-packages/numpy/lib/histograms.py:323, in _get_outer_edges(a, range)
#     321     first_edge, last_edge = a.min(), a.max()
#     322     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# --> 323         raise ValueError(
#     324             "autodetected range of [{}, {}] is not finite".format(first_edge, last_edge))
#     326 # expand empty range to avoid divide by zero
#     327 if first_edge == last_edge:
#
# ValueError: autodetected range of [nan, nan] is not finite

# %% [markdown]
# # Comparison

# %%
import pandas as pd
from cev.widgets import Embedding, EmbeddingComparisonWidget

# change column names 
spec_cmp = umap_embeddings_spec.rename(columns={'UMAP_1': 'x', 'UMAP_2': 'y', 'mark_label': 'label'}, inplace=False)
clip_cmp = umap_embeddings_clip.rename(columns={'UMAP_1': 'x', 'UMAP_2': 'y', 'mark_label': 'label'}, inplace=False)
lit_cmp = umap_embeddings_lit.rename(columns={'UMAP_1': 'x', 'UMAP_2': 'y', 'mark_label': 'label'}, inplace=False)
bio_cmp = umap_embeddings_bio.rename(columns={'UMAP_1': 'x', 'UMAP_2': 'y', 'mark_label': 'label'}, inplace=False)


# Convert 'Column' to category dtype before using .cat accessor
spec_cmp['label'] = spec_cmp['label'].astype('category')
clip_cmp['label'] = clip_cmp['label'].astype('category')
lit_cmp['label'] = lit_cmp['label'].astype('category')
bio_cmp['label'] = bio_cmp['label'].astype('category')

widget = EmbeddingComparisonWidget(
    # left_embedding=Embedding.from_df(spec_cmp),
    left_embedding=Embedding.from_df(spec_cmp),
    right_embedding=Embedding.from_df(bio_cmp),
    titles=["Embeddings from Spec", "Embeddings from Images with CLIP"],
    metric="confusion", # or 'neighborhood', 'confusion', 'abundance'
    selection="synced",
    auto_zoom=True,
    row_height=500,
    background="white",
)
widget
# Out:
# EmbeddingComparisonWidget(children=(VBox(children=(HBox(children=(WidthOptimizer(), Dropdown(description='Metr…
