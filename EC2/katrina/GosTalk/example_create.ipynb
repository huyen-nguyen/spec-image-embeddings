# %%
from GosTalk import GosTalk_ChatGPT 
from FineTune import Chat_FineTune_Message
import openai
import os
import gosling as gos

# %%
from dotenv import load_dotenv
load_dotenv()

API_KEY = os.environ.get('OPENAI_API_KEY')
#%%
if API_KEY:
    openai.api_key = API_KEY    # API_KEY is the key to access the openai API, you can get it from https://platform.openai.com/account/api-keys
else:
    print('Please set the OPENAI_API_KEY environment variable.\n You can get it from https://platform.openai.com/account/api-keys')
#%%

# %%
bot = GosTalk_ChatGPT(Chat_FineTune_Message) # initialize the bot and fine tune with grammar rules
bot.ask('draw a bar chart, the x axis is position, the y axis is peak, the color is sample') # ask the bot a question
# Out:
# This specification will draw a bar chart with one track, using the data provided in the example. The x-axis is specified as genomic with the field name "position", and the y-axis is specified as quantitative with the field name "peak". The color is specified as nominal with the field name "sample". The width and height of the track are specified as 600 and 200, respectively.
#
# {
#   "title": "Bar Chart",
#   "views": [
#     {
#       "tracks": [
#         {
#           "data": {
#             "url": "https://server.gosling-lang.org/api/v1/tileset_info/?d=cistrome-multivec",
#             "type": "multivec",
#             "row": "sample",
#             "column": "position",
#             "value": "peak",
#             "categories": ["sample 1"]
#           },
#           "mark": "bar",
#           "x": {"field": "position", "type": "genomic"},
#           "y": {"field": "peak", "type": "quantitative"},
#           "color": {"field": "sample", "type": "nominal"},
# ...

# %%
bot.ask('make the bar chart wider and use color to encode four different sample')
# Out:
# I increased the width of the chart to 800 and added all four samples to the "categories" field in the data specification, so that each sample is now represented by a different color.
#
# {
#   "title": "Bar Chart",
#   "views": [
#     {
#       "tracks": [
#         {
#           "data": {
#             "url": "https://server.gosling-lang.org/api/v1/tileset_info/?d=cistrome-multivec",
#             "type": "multivec",
#             "row": "sample",
#             "column": "position",
#             "value": "peak",
#             "categories": ["sample 1", "sample 2", "sample 3", "sample 4"]
#           },
#           "mark": "bar",
#           "x": {"field": "position", "type": "genomic"},
#           "y": {"field": "peak", "type": "quantitative"},
#           "color": {"field": "sample", "type": "nominal"},
#           "width": 800,
#           "height": 200
#         }
#       ]
#     }
#   ]
# }
# View({
#   title: 'Bar Chart',
# ...
